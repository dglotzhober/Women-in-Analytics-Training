# %% [markdown]
# # Additional Resources - Classification

# %% [markdown]
# - Scikit-learn docs:
#   - [Classification examples](https://scikit-learn.org/stable/auto_examples/index.html#classification)
#   - [sklearn Datasets list](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.datasets)
#   - [`make_classification()`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_classification.html#sklearn.datasets.make_classification) - Generate a random n-class classification problem
#   - [SVR classifiers](https://scikit-learn.org/stable/modules/svm.html#classification)
#   - [Ridge classification](https://scikit-learn.org/stable/modules/linear_model.html#classification)
# - [Logistic Regression](https://www.stat.cmu.edu/~cshalizi/uADA/12/lectures/ch12.pdf) (CMU)
# - [Keras](https://keras.io/), a Python deep learning library
# - [Practical Text Classification With Python and Keras](https://realpython.com/python-keras-text-classification/) (Real Python)
