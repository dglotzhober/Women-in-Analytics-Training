# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # This notebook provides some practice problems to supplement the Intro to Probability and Statistics Unit in the Women in Analytics Training curriculum.
#
# We will practice doing basic probability and statistics in Python through various examples. It is important to note that there are many different ways to achieve the same results in Python. We will only be looking at a few of the most common ways to approach these problems. As you are reviewing and practicing, we encourage you to go back and try completing these using alternative methods so that you can understand the pros and cons of each technique

# %% [markdown]
# ### Loading the Data

# %%
data = pd.read_csv('airbnb.csv')
# Out:
# C:\Users\muammar\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Let's take an initial look at the data

# %%
data.dtypes
# Out:
# accommodates                int64
# bathrooms                 float64
# bed_type                   object
# bedrooms                    int64
# beds                        int64
# cancellation_policy        object
# city                       object
# cleaning_fee                 bool
# first_review               object
# host_has_profile_pic       object
# host_identity_verified     object
# host_response_rate          int64
# host_since                 object
# instant_bookable           object
# last_review                object
# latitude                  float64
# longitude                 float64
# neighbourhood              object
# number_of_reviews           int64
# property_type              object
# review_scores_rating        int64
# room_type                  object
# zipcode                    object
# dtype: object

# %%
data.head()
# Out:
#    accommodates  bathrooms  bed_type  bedrooms  beds cancellation_policy city  \
# 0             1        1.0  Real Bed         1     1            flexible   SF
# 1             1        1.0  Real Bed         1     1            flexible   LA
# 2             2        1.0  Real Bed         1     1            moderate   LA
# 3             2        1.0  Real Bed         1     1            flexible   LA
# 4             2        1.0  Real Bed         1     1            moderate   LA
#
#    cleaning_fee first_review host_has_profile_pic  ... instant_bookable  \
# 0          True    8/15/2016                    t  ...                t
# 1         False          NaN                    t  ...                f
# 2          True   11/16/2011                    t  ...                f
# 3         False          NaN                    t  ...                f
# 4          True     9/6/2010                    t  ...                f
#
#    last_review   latitude   longitude neighbourhood  number_of_reviews  \
# 0    1/18/2017  37.773742 -122.391503   Mission Bay                  5
# 1          NaN  34.135680 -118.400691   Studio City                  6
# 2     4/8/2017  34.192617 -118.136794      Altadena                136
# 3          NaN  34.023618 -118.501174  Santa Monica                  0
# 4    2/28/2017  34.104213 -118.260040   Silver Lake                 16
#
#    property_type review_scores_rating        room_type              zipcode
# 0      Apartment                   95     Private room  95202\r\r\r\r\r\r\r
# 1          House                  100     Private room           91604-3646
# 2      Apartment                   96  Entire home/apt           91001-2243
# 3      Apartment                   96     Private room           90403-2638
# 4          House                   99     Private room           90039-2715
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Practice Questions

# %% [markdown]
# 1. We expect that in general Airbnbs will have one bed per bedroom. Let's see if that is the case by comparing the average number of beds with the average number of bedrooms
# 2. For an Airbnb to be successful, hosts should have high response rates. We can assume that most hosts will have a high response rate and there will be few hosts with low response rates. Let's look into the distribution of response rates by comparing the quartiles. (bonus: use a histogram to get a better visual)
# 3. Let's say that we are feeling pretty spontaneous and we want to randomly pick an airbnb for our trip. What is the likelihood that we will pick an Airbnb that is an apartment?
# 4. On average what are the review scores for Apartments vs. the average review scores for Houses?
# 5. What is the liklihood that we will randomly pick and Airbnb that is an apartment AND has a review score greater than 95?
# 6. Given that we pick an Airbnb that is in Santa Monica, what is the chance that it will accommodate more than 3 people?
